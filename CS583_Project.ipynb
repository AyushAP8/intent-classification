# %%
import pandas as pd
import json
import re
import nltk
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report,accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier

# %%
with open('data_full.json') as json_file: 
    data_dict = json.load(json_file) 

train_data = data_dict['train']
val_data = data_dict['val']
test_data = data_dict['test']

# %%
train_df = pd.DataFrame(train_data, columns =['query', 'intent'])
val_df = pd.DataFrame(val_data, columns =['query', 'intent'])
test_df = pd.DataFrame(test_data, columns =['query', 'intent'])

# %%
df = train_df.append(val_df).append(test_df)
df.shape
# Out:
# (22500, 2)

# %%
sents = list(df["query"])
intents = list(df["intent"])

# %%
cleaned_sents = []
lemmatizer = WordNetLemmatizer()
for sent in sents:
    cleaned_sent = re.sub(r'[^ a-z A-Z 0-9]', " ", sent)
    word = nltk.tokenize.word_tokenize(cleaned_sent)
    cleaned_sents.append([lemmatizer.lemmatize(w.lower()) for w in word])

# %%
print(cleaned_sents[:5])
# Out:
# [['what', 'expression', 'would', 'i', 'use', 'to', 'say', 'i', 'love', 'you', 'if', 'i', 'were', 'an', 'italian'], ['can', 'you', 'tell', 'me', 'how', 'to', 'say', 'i', 'do', 'not', 'speak', 'much', 'spanish', 'in', 'spanish'], ['what', 'is', 'the', 'equivalent', 'of', 'life', 'is', 'good', 'in', 'french'], ['tell', 'me', 'how', 'to', 'say', 'it', 'is', 'a', 'beautiful', 'morning', 'in', 'italian'], ['if', 'i', 'were', 'mongolian', 'how', 'would', 'i', 'say', 'that', 'i', 'am', 'a', 'tourist']]

# %%
tfidf = TfidfVectorizer(max_features=15000, lowercase=False, tokenizer= lambda text : text, ngram_range=(1,2))
cleaned_sents_tfidf = tfidf.fit_transform(cleaned_sents).toarray()

# %%
X_train, X_test, y_train, y_test = train_test_split(cleaned_sents_tfidf, intents, test_size=0.30, random_state=42)

# %%
mlp_classifier = MLPClassifier()
MLP = MLPClassifier()
trained_classifier = MLP.fit(X_train, y_train)
y_pred = MLP.predict(X_test)
print('classification report of the multi layer perceptron model : \n',classification_report(y_test, y_pred))
print('Accuracy of the multi layer perceptron model : ',accuracy_score(y_test, y_pred))
# Out:
# classification report of the multi layer perceptron model :
#                             precision    recall  f1-score   support
#
#       accept_reservations       0.97      0.94      0.95        33
#           account_blocked       0.90      0.90      0.90        49
#                     alarm       0.95      1.00      0.98        41
#        application_status       0.97      0.95      0.96        40
#                       apr       0.95      1.00      0.98        40
#             are_you_a_bot       0.98      0.94      0.96        54
#                   balance       0.94      0.96      0.95        52
#              bill_balance       0.88      0.83      0.86        36
#                  bill_due       0.92      0.92      0.92        52
#               book_flight       1.00      1.00      1.00        48
#                book_hotel       0.95      0.95      0.95        40
#                calculator       0.93      0.95      0.94        44
#                  calendar       0.85      0.80      0.83        41
#           calendar_update       0.91      0.91      0.91        46
#                  calories       0.98      1.00      0.99        42
#                    cancel       0.80      0.85      0.82        47
#        cancel_reservation       0.97      0.90      0.94        41
#                car_rental       0.96      0.98      0.97        49
#             card_declined       1.00      0.94      0.97        36
#                  carry_on       1.00      1.00      1.00        47
#             change_accent       1.00      0.96      0.98        53
#            change_ai_name       0.95      0.89      0.92        47
#           change_language       0.95      0.93      0.94        42
#              change_speed       0.91      0.95      0.93        41
#          change_user_name       0.92      0.95      0.94        38
#             change_volume       0.98      0.86      0.91        50
#       confirm_reservation       0.98      0.98      0.98        46
#                 cook_time       0.98      0.95      0.96        42
#              credit_limit       0.94      0.96      0.95        50
#       credit_limit_change       1.00      0.92      0.96        37
#              credit_score       0.96      0.92      0.94        52
#          current_location       0.85      0.92      0.88        37
#              damaged_card       0.96      1.00      0.98        44
#                      date       0.94      0.94      0.94        51
#                definition       0.98      0.95      0.97        44
#            direct_deposit       0.98      0.98      0.98        45
#                directions       0.94      0.92      0.93        37
#                  distance       0.95      0.93      0.94        42
#          do_you_have_pets       0.98      0.98      0.98        47
#             exchange_rate       1.00      1.00      1.00        44
#           expiration_date       0.90      1.00      0.95        47
#                find_phone       0.95      0.97      0.96        38
#             flight_status       0.98      0.98      0.98        42
#                 flip_coin       1.00      1.00      1.00        51
#                 food_last       1.00      0.95      0.98        42
#            freeze_account       0.92      0.90      0.91        52
#                  fun_fact       0.96      1.00      0.98        54
#                       gas       0.96      0.96      0.96        50
#                  gas_type       0.96      0.94      0.95        54
#                   goodbye       0.82      0.84      0.83        44
#                  greeting       0.62      0.92      0.74        59
#                  how_busy       0.98      0.96      0.97        47
#           how_old_are_you       0.90      0.90      0.90        39
#      improve_credit_score       0.93      0.97      0.95        39
#                    income       0.87      1.00      0.93        39
#   ingredient_substitution       0.96      0.96      0.96        48
#          ingredients_list       0.84      0.86      0.85        42
#                 insurance       0.97      0.97      0.97        39
#          insurance_change       0.98      0.98      0.98        43
#             interest_rate       1.00      0.96      0.98        53
#        international_fees       1.00      1.00      1.00        47
#        international_visa       0.95      1.00      0.97        35
#                jump_start       1.00      1.00      1.00        33
#          last_maintenance       0.96      0.92      0.94        51
#              lost_luggage       1.00      1.00      1.00        43
#                 make_call       0.94      0.92      0.93        37
#                     maybe       0.76      0.96      0.85        50
#           meal_suggestion       0.92      0.94      0.93        35
#           meaning_of_life       1.00      0.98      0.99        51
#    measurement_conversion       0.95      0.95      0.95        40
#          meeting_schedule       0.91      0.93      0.92        45
#               min_payment       1.00      0.93      0.97        46
#                       mpg       0.98      0.96      0.97        46
#                  new_card       0.98      0.96      0.97        45
#              next_holiday       0.94      0.96      0.95        48
#                 next_song       1.00      0.96      0.98        50
#                        no       0.92      0.77      0.84        47
#            nutrition_info       1.00      0.92      0.96        53
#            oil_change_how       0.87      1.00      0.93        39
#           oil_change_when       0.93      0.84      0.88        44
#                     order       0.98      0.91      0.94        46
#              order_checks       1.00      1.00      1.00        48
#              order_status       0.95      0.93      0.94        41
#                  pay_bill       0.90      0.93      0.91        40
#                    payday       0.98      0.91      0.94        44
#                pin_change       1.00      1.00      1.00        45
#                play_music       0.98      0.93      0.95        45
#                 plug_type       1.00      0.96      0.98        50
#               pto_balance       0.89      0.92      0.90        36
#               pto_request       0.94      0.94      0.94        33
#        pto_request_status       0.94      0.98      0.96        47
#                  pto_used       0.98      0.93      0.95        44
#                    recipe       0.93      0.80      0.86        50
#            redeem_rewards       0.96      0.92      0.94        49
#                  reminder       0.98      0.98      0.98        42
#           reminder_update       0.88      0.97      0.92        30
#                    repeat       0.91      0.95      0.93        42
# replacement_card_duration       0.98      0.90      0.94        51
#              report_fraud       1.00      0.98      0.99        47
#          report_lost_card       0.97      0.97      0.97        36
#            reset_settings       0.98      1.00      0.99        43
#    restaurant_reservation       0.92      0.94      0.93        47
#        restaurant_reviews       1.00      0.98      0.99        53
#     restaurant_suggestion       0.90      1.00      0.95        54
#           rewards_balance       0.95      0.95      0.95        40
#                 roll_dice       1.00      1.00      1.00        48
#             rollover_401k       1.00      0.98      0.99        44
#                   routing       1.00      1.00      1.00        55
#      schedule_maintenance       0.95      0.95      0.95        55
#          schedule_meeting       0.98      0.98      0.98        52
#            share_location       0.95      0.89      0.92        46
#             shopping_list       0.85      0.91      0.88        45
#      shopping_list_update       0.94      0.92      0.93        52
#                smart_home       0.93      0.97      0.95        39
#                  spelling       0.97      0.97      0.97        39
#          spending_history       0.86      0.93      0.89        45
#               sync_device       0.96      0.96      0.96        50
#                     taxes       0.98      0.96      0.97        54
#                 tell_joke       1.00      0.98      0.99        43
#                      text       1.00      0.96      0.98        47
#                 thank_you       0.98      0.86      0.91        49
#                      time       0.97      0.90      0.94        42
#                     timer       0.98      0.98      0.98        45
#                  timezone       1.00      1.00      1.00        47
#               tire_change       0.93      0.98      0.95        43
#             tire_pressure       0.98      1.00      0.99        45
#                 todo_list       0.84      0.93      0.88        45
#          todo_list_update       0.94      0.86      0.90        51
#                   traffic       1.00      0.98      0.99        54
#              transactions       0.96      0.85      0.90        54
#                  transfer       0.94      0.97      0.96        34
#                 translate       0.97      1.00      0.99        38
#              travel_alert       0.95      0.97      0.96        36
#       travel_notification       0.98      0.95      0.96        43
#         travel_suggestion       0.98      0.87      0.92        47
#                      uber       1.00      1.00      1.00        45
#           update_playlist       0.98      1.00      0.99        47
#                 user_name       0.80      0.93      0.86        40
#                  vaccines       1.00      1.00      1.00        47
#                        w2       1.00      0.96      0.98        46
#                   weather       0.92      0.88      0.90        52
#     what_are_your_hobbies       1.00      0.97      0.98        32
#        what_can_i_ask_you       0.82      0.95      0.88        44
#         what_is_your_name       0.92      0.82      0.87        55
#                 what_song       0.98      0.96      0.97        46
#        where_are_you_from       0.85      0.95      0.90        43
#              whisper_mode       0.96      0.88      0.92        51
#       who_do_you_work_for       0.97      0.82      0.89        44
#              who_made_you       0.88      0.92      0.90        50
#                       yes       0.76      0.86      0.81        44
#
#                  accuracy                           0.94      6750
#                 macro avg       0.95      0.94      0.94      6750
#              weighted avg       0.95      0.94      0.94      6750
#
# Accuracy of the multi layer perceptron model :  0.9435555555555556

# %% [markdown]
# # Bonus

# %%
nb_classifier = MultinomialNB()
NB = MultinomialNB()
trained_classifier = NB.fit(X_train, y_train)
y_pred = NB.predict(X_test)
print('classification report of the naive bayes model : \n',classification_report(y_test, y_pred))
print('Accuracy of the naive bayes model  : ',accuracy_score(y_test, y_pred))
# Out:
# classification report of the naive bayes model :
#                             precision    recall  f1-score   support
#
#       accept_reservations       0.97      0.94      0.95        33
#           account_blocked       0.88      0.92      0.90        49
#                     alarm       0.98      1.00      0.99        41
#        application_status       0.88      0.93      0.90        40
#                       apr       0.87      1.00      0.93        40
#             are_you_a_bot       0.91      0.96      0.94        54
#                   balance       0.98      0.88      0.93        52
#              bill_balance       0.68      0.89      0.77        36
#                  bill_due       1.00      0.81      0.89        52
#               book_flight       1.00      1.00      1.00        48
#                book_hotel       0.90      0.93      0.91        40
#                calculator       0.94      0.75      0.84        44
#                  calendar       0.80      0.78      0.79        41
#           calendar_update       0.88      0.83      0.85        46
#                  calories       0.87      0.98      0.92        42
#                    cancel       0.97      0.77      0.86        47
#        cancel_reservation       0.88      0.93      0.90        41
#                car_rental       0.98      0.96      0.97        49
#             card_declined       0.82      0.92      0.87        36
#                  carry_on       1.00      1.00      1.00        47
#             change_accent       1.00      0.94      0.97        53
#            change_ai_name       0.91      0.85      0.88        47
#           change_language       0.95      0.93      0.94        42
#              change_speed       0.84      0.90      0.87        41
#          change_user_name       0.81      0.76      0.78        38
#             change_volume       0.98      0.86      0.91        50
#       confirm_reservation       0.95      0.91      0.93        46
#                 cook_time       0.90      0.86      0.88        42
#              credit_limit       0.96      0.94      0.95        50
#       credit_limit_change       0.95      0.97      0.96        37
#              credit_score       0.96      0.92      0.94        52
#          current_location       0.76      0.95      0.84        37
#              damaged_card       0.95      0.84      0.89        44
#                      date       0.90      0.90      0.90        51
#                definition       0.80      0.75      0.78        44
#            direct_deposit       0.96      0.98      0.97        45
#                directions       0.91      0.81      0.86        37
#                  distance       0.84      0.90      0.87        42
#          do_you_have_pets       0.82      0.98      0.89        47
#             exchange_rate       1.00      0.95      0.98        44
#           expiration_date       0.90      0.96      0.93        47
#                find_phone       0.77      0.97      0.86        38
#             flight_status       0.95      0.95      0.95        42
#                 flip_coin       1.00      1.00      1.00        51
#                 food_last       0.92      0.83      0.88        42
#            freeze_account       0.98      0.90      0.94        52
#                  fun_fact       0.96      0.96      0.96        54
#                       gas       0.98      0.86      0.91        50
#                  gas_type       0.87      0.98      0.92        54
#                   goodbye       0.80      0.80      0.80        44
#                  greeting       1.00      0.71      0.83        59
#                  how_busy       0.98      0.91      0.95        47
#           how_old_are_you       0.74      0.82      0.78        39
#      improve_credit_score       0.86      0.92      0.89        39
#                    income       0.84      0.82      0.83        39
#   ingredient_substitution       0.98      0.98      0.98        48
#          ingredients_list       0.78      0.90      0.84        42
#                 insurance       0.97      0.97      0.97        39
#          insurance_change       0.95      0.98      0.97        43
#             interest_rate       1.00      0.94      0.97        53
#        international_fees       0.98      1.00      0.99        47
#        international_visa       0.63      0.97      0.76        35
#                jump_start       0.92      1.00      0.96        33
#          last_maintenance       0.84      0.94      0.89        51
#              lost_luggage       0.98      0.95      0.96        43
#                 make_call       0.94      0.81      0.87        37
#                     maybe       0.86      0.84      0.85        50
#           meal_suggestion       0.88      0.86      0.87        35
#           meaning_of_life       0.86      0.98      0.92        51
#    measurement_conversion       0.93      0.95      0.94        40
#          meeting_schedule       0.91      0.91      0.91        45
#               min_payment       0.92      0.96      0.94        46
#                       mpg       0.93      0.91      0.92        46
#                  new_card       0.95      0.91      0.93        45
#              next_holiday       0.93      0.90      0.91        48
#                 next_song       0.92      0.98      0.95        50
#                        no       0.90      0.79      0.84        47
#            nutrition_info       1.00      0.87      0.93        53
#            oil_change_how       0.78      0.97      0.86        39
#           oil_change_when       0.85      0.89      0.87        44
#                     order       0.90      0.61      0.73        46
#              order_checks       0.98      1.00      0.99        48
#              order_status       0.94      0.80      0.87        41
#                  pay_bill       0.83      0.85      0.84        40
#                    payday       0.89      0.75      0.81        44
#                pin_change       0.96      1.00      0.98        45
#                play_music       0.97      0.76      0.85        45
#                 plug_type       1.00      0.92      0.96        50
#               pto_balance       0.69      0.92      0.79        36
#               pto_request       0.86      0.94      0.90        33
#        pto_request_status       0.96      0.94      0.95        47
#                  pto_used       0.84      0.93      0.88        44
#                    recipe       0.94      0.68      0.79        50
#            redeem_rewards       0.96      0.90      0.93        49
#                  reminder       0.97      0.93      0.95        42
#           reminder_update       0.56      0.97      0.71        30
#                    repeat       0.87      0.95      0.91        42
# replacement_card_duration       0.90      0.92      0.91        51
#              report_fraud       1.00      0.96      0.98        47
#          report_lost_card       0.81      0.97      0.89        36
#            reset_settings       0.98      1.00      0.99        43
#    restaurant_reservation       0.90      0.96      0.93        47
#        restaurant_reviews       0.98      0.92      0.95        53
#     restaurant_suggestion       0.91      0.93      0.92        54
#           rewards_balance       0.85      0.97      0.91        40
#                 roll_dice       1.00      1.00      1.00        48
#             rollover_401k       0.98      0.98      0.98        44
#                   routing       1.00      0.98      0.99        55
#      schedule_maintenance       1.00      0.87      0.93        55
#          schedule_meeting       0.93      0.96      0.94        52
#            share_location       1.00      0.80      0.89        46
#             shopping_list       0.67      0.87      0.76        45
#      shopping_list_update       0.91      0.79      0.85        52
#                smart_home       0.92      0.87      0.89        39
#                  spelling       0.95      0.90      0.92        39
#          spending_history       0.78      0.93      0.85        45
#               sync_device       0.98      0.94      0.96        50
#                     taxes       1.00      0.89      0.94        54
#                 tell_joke       0.89      0.95      0.92        43
#                      text       0.98      0.87      0.92        47
#                 thank_you       1.00      0.82      0.90        49
#                      time       0.80      0.95      0.87        42
#                     timer       0.96      0.96      0.96        45
#                  timezone       0.98      0.96      0.97        47
#               tire_change       0.80      0.95      0.87        43
#             tire_pressure       0.96      0.96      0.96        45
#                 todo_list       0.71      0.89      0.79        45
#          todo_list_update       0.90      0.75      0.82        51
#                   traffic       0.96      0.94      0.95        54
#              transactions       0.95      0.74      0.83        54
#                  transfer       0.87      1.00      0.93        34
#                 translate       0.93      0.97      0.95        38
#              travel_alert       0.83      0.94      0.88        36
#       travel_notification       0.78      1.00      0.88        43
#         travel_suggestion       0.97      0.77      0.86        47
#                      uber       0.98      0.98      0.98        45
#           update_playlist       0.94      0.98      0.96        47
#                 user_name       0.58      0.85      0.69        40
#                  vaccines       0.96      0.96      0.96        47
#                        w2       0.94      0.96      0.95        46
#                   weather       0.93      0.73      0.82        52
#     what_are_your_hobbies       0.79      0.97      0.87        32
#        what_can_i_ask_you       0.83      0.89      0.86        44
#         what_is_your_name       0.93      0.71      0.80        55
#                 what_song       0.90      0.96      0.93        46
#        where_are_you_from       0.81      0.91      0.86        43
#              whisper_mode       1.00      0.90      0.95        51
#       who_do_you_work_for       0.89      0.89      0.89        44
#              who_made_you       0.98      0.80      0.88        50
#                       yes       0.97      0.73      0.83        44
#
#                  accuracy                           0.90      6750
#                 macro avg       0.91      0.90      0.90      6750
#              weighted avg       0.91      0.90      0.90      6750
#
# Accuracy of the naive bayes model  :  0.9017777777777778
